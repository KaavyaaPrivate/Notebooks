# %%
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt 
from pandas import DataFrame 
from sklearn import datasets 
from sklearn.mixture import GaussianMixture

# %%
Df = pd.read_csv("Desktop/6D_sample_pca_9.csv")

# %%
data  = Df.values
# select first four columns  
X = data[:, :4] 
# turn it into a dataframe 
p = pd.DataFrame(X)
# plot the data 
plt.scatter(p[0], p[1], p[2], p[3] )
plt.xlabel('k')
plt.ylabel('x')
plt.title('6D Unclustered Data')
# Out:
# Text(0.5, 1.0, '6D Unclustered Data')

# %%
gmm = GaussianMixture(n_components=25).fit(pd.DataFrame(p))
labels = gmm.predict(pd.DataFrame(p))
plt.scatter(p[0], p[1], c=labels, s=5,cmap='tab20c');
plt.xlabel('k')
plt.ylabel('x')
plt.title('6D-Gaussian Mixture Model')
# Out:
# Text(0.5, 1.0, '6D-Gaussian Mixture Model')

# %%
gmm = GaussianMixture(n_components=35).fit(pd.DataFrame(p))
labels = gmm.predict(pd.DataFrame(p))
plt.scatter(p[0], p[1], c=labels, s=5,cmap='tab20c');
plt.xlabel('k')
plt.ylabel('x')
plt.title('6D-Gaussian Mixture Model')
# Out:
# Text(0.5, 1.0, '6D-Gaussian Mixture Model')

# %%
print("Gaussian Mixture Model Mean")
print('\n')
print(gmm.means_)
print('\n')
print("Gaussian Mixture Model Covariance")
print('\n')
print(gmm.covariances_)
# Out:
# Gaussian Mixture Model Mean
#
#
# [[-6.56787451e-01 -2.93757432e-01 -9.59220554e-02  3.28362028e-01]
#  [ 6.62323885e-02  8.56481753e-01 -3.68959773e-01  7.44705563e-02]
#  [ 4.82748367e-01 -1.69383332e+00 -2.40530945e-01  7.43162728e-01]
#  [-7.86990479e-01  5.95929046e-01 -1.84235524e-01 -1.85681794e-03]
#  [ 7.78681484e-01  1.42226963e-01 -8.28119376e-02 -2.05717816e-01]
#  [ 2.95305576e-01 -6.55057742e-01  1.76330156e+00 -1.13213055e+00]
#  [-2.07751880e+00 -1.41589635e+00 -1.28832356e+00 -2.03103994e+00]
#  [-7.84237567e-01 -1.04735824e+00 -7.93476950e-01  1.05670739e+00]
#  [-1.33827835e+00  7.40538337e-01  2.28120359e+00  1.82513636e+00]
#  [ 8.18949767e-01 -1.57434181e+00  9.16639969e-01 -2.74843584e-01]
#  [ 9.13345214e-01 -6.89619236e-02 -1.79894723e+00 -2.22380003e+00]
#  [-2.02339015e-01 -1.47145420e-02  4.86564951e-01  1.03595383e+00]
#  [ 1.96201059e+00  1.72660156e+00 -6.18702238e-01  1.05442340e+00]
#  [-1.09116907e+00 -2.38741551e-01 -2.36283690e-01 -8.86668803e-01]
# ...

# %%
Dt = pd.read_csv("Desktop/3D_sample_pca_1.csv")

# %%
data  = Dt.values
# select first four columns  
X = data[:, :4] 
# turn it into a dataframe 
p = pd.DataFrame(X)
# plot the data 
plt.scatter(p[0], p[1], p[2])
plt.xlabel('k')
plt.ylabel('x')
plt.title('3D Unclustered Data')
# Out:
# Text(0.5, 1.0, '3D Unclustered Data')

# %%
gmm = GaussianMixture(n_components=25).fit(pd.DataFrame(p))
labels = gmm.predict(pd.DataFrame(p))
plt.scatter(p[0], p[1], c=labels, s=5,cmap='tab20c');
plt.xlabel('k')
plt.ylabel('x')
plt.title('3D-Gaussian Mixture Model')
# Out:
# Text(0.5, 1.0, '3D-Gaussian Mixture Model')

# %%
gmm = GaussianMixture(n_components=100).fit(pd.DataFrame(p))
labels = gmm.predict(pd.DataFrame(p))
plt.scatter(p[0], p[1], c=labels, s=5,cmap='tab20c');
plt.xlabel('k')
plt.ylabel('x')
plt.title('3D-Gaussian Mixture Model')
# Out:
# Text(0.5, 1.0, '3D-Gaussian Mixture Model')

# %%
print("Gaussian Mixture Model Mean")
print('\n')
print(gmm.means_)
print('\n')
print("Gaussian Mixture Model Covariance")
print('\n')
print(gmm.covariances_)
# Out:
# Gaussian Mixture Model Mean
#
#
# [[ 0.03758238 -0.79167651  0.42283956]
#  [-1.35365054  0.61720616 -0.30196778]
#  [ 2.28851325  1.7904921  -0.2583744 ]
#  [ 2.06843951 -1.93905161 -0.81304985]
#  [ 0.24272421  0.72591814 -0.06069289]
#  [ 1.01811595  0.49405553  1.34526665]
#  [-0.64993585  0.63397024  0.23657122]
#  [-0.9159531  -0.50958129 -0.34813466]
#  [-0.27811195 -1.27262181 -0.36683396]
#  [ 1.08909131 -1.67444303 -0.09917078]
#  [ 3.18235655  2.07777885 -0.65694496]
#  [-0.13255218 -0.32167269  0.76328996]
#  [ 1.04238777 -0.55910881  0.80052115]
#  [-1.6927244   0.60724663 -0.45188989]
#  [ 0.2801855  -1.21578478 -0.03566084]
#  [ 1.67159705  1.03891244  0.13107549]
#  [-0.16249891 -0.20914738  0.39336932]
#  [ 3.88988307  2.28671723 -0.9158389 ]
#  [-0.17536093  0.40879379  0.81598765]
#  [-1.06287083  0.50692194  0.23080705]
#  [ 0.55991128 -1.71610456  0.03877664]
#  [-1.55017111  0.10471267 -0.34219711]
#  [-0.73142536  0.59664791 -0.06219379]
# ...
